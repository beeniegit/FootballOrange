# %%
from NewStreamlitApplication.tools.sqlite_tool import SqliteTool

tool = SqliteTool()

# %%
QUERY = """
SELECT *
FROM matches
ORDER BY Date DESC;
"""

result = tool.EXECUTE(QUERY)
for row in result:
    print(row)
# Out:
# (37, '2024-05-19', '16:00', 'Premier League', 'Matchweek 38', 'Sun', 'Home', 'W', 3, 1, 'West Ham', 1.9, 0.4, 71.0, 55097.0, 'Kyle Walker', '4-1-4-1', 'John Brooks', 'Match Report', '', 28.0, 12.0, 17.9, 2.0, 0.0, 0.0, 2024, 'ManchesterCity')
# (75, '2024-05-19', '16:00', 'Premier League', 'Matchweek 38', 'Sun', 'Home', 'W', 2, 1, 'Everton', 2.9, 0.6, 68.0, 60312.0, 'Martin Ødegaard', '4-3-3', 'Michael Oliver', 'Match Report', '', 26.0, 5.0, 14.1, 0.0, 0.0, 0.0, 2024, 'Arsenal')
# (113, '2024-05-19', '16:00', 'Premier League', 'Matchweek 38', 'Sun', 'Home', 'W', 2, 0, 'Wolves', 4.5, 0.5, 67.0, 60059.0, 'Virgil van Dijk', '4-3-3', 'Chris Kavanagh', 'Match Report', '', 36.0, 13.0, 14.8, 0.0, 0.0, 0.0, 2024, 'Liverpool')
# (151, '2024-05-19', '16:00', 'Premier League', 'Matchweek 38', 'Sun', 'Away', 'L', 0, 5, 'Crystal Palace', 0.9, 2.5, 46.0, 25191.0, 'John McGinn', '4-4-2', 'Darren Bond', 'Match Report', '', 8.0, 2.0, 13.8, 0.0, 0.0, 0.0, 2024, 'AstonVilla')
# ...

# %%
import pandas as pd

df = pd.DataFrame(result, columns=['Date', 'Venue', 'Team', 'Opponent', 'Result'])

df
# Out:
#            Date Venue              Team         Opponent Result
# 0    2024-05-19  Home    ManchesterCity         West Ham      W
# 1    2024-05-19  Home           Arsenal          Everton      W
# 2    2024-05-19  Home         Liverpool           Wolves      W
# 3    2024-05-19  Away        AstonVilla   Crystal Palace      L
# 4    2024-05-19  Away  TottenhamHotspur    Sheffield Utd      W
# ..          ...   ...               ...              ...    ...
# 754  2023-08-12  Home           Everton           Fulham      L
# 755  2023-08-12  Away  NottinghamForest          Arsenal      L
# 756  2023-08-12  Away         LutonTown         Brighton      L
# 757  2023-08-12  Home   SheffieldUnited   Crystal Palace      L
# 758  2023-08-11  Home           Burnley  Manchester City      L
#
# [759 rows x 5 columns]

# %%
import pandas as pd

df = pd.DataFrame(result, columns=['Date', 'Venue', 'Team', 'Opponent', 'Result'])

df
